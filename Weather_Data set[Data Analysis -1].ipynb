# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Admin\Desktop\DATA SCIENCE\PROJECTS\Project - 1 _ Data Analysis with Python _ Weather Dataset{ Excel }.csv")

# %% [markdown]
# # #exploring DATA

# %%
data.head(15)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 2    1/1/2012 2:00    -1.8              -3.4         89                7
# 3    1/1/2012 3:00    -1.5              -3.2         88                6
# 4    1/1/2012 4:00    -1.5              -3.3         88                7
# 5    1/1/2012 5:00    -1.4              -3.3         87                9
# 6    1/1/2012 6:00    -1.5              -3.1         89                7
# 7    1/1/2012 7:00    -1.4              -3.6         85                7
# 8    1/1/2012 8:00    -1.4              -3.6         85                9
# 9    1/1/2012 9:00    -1.3              -3.1         88               15
# 10  1/1/2012 10:00    -1.0              -2.3         91                9
# 11  1/1/2012 11:00    -0.5              -2.1         89                7
# ...

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 480.4+ KB

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Weather'].value_counts().head(15)
# Out:
# Mainly Clear         2106
# Mostly Cloudy        2069
# Cloudy               1728
# Clear                1326
# Snow                  390
# Rain                  306
# Rain Showers          188
# Fog                   150
# Rain,Fog              116
# Drizzle,Fog            80
# Snow Showers           60
# Drizzle                41
# Snow,Fog               37
# Snow,Blowing Snow      19
# Rain,Snow              18
# Name: Weather, dtype: int64

# %% [markdown]
# # #Find all Unique 'Windspeed' Values in data

# %%
#data.head(15)
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# # #Find the Number of times when the 'Weather is =Clear'

# %%
#data.head(15)

# %%
data[data.Weather == 'Clear'].head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# # #Find The Number of times When 'windspeed ' was Exactly 4km/hr

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# # # Find out all Null Values in the Data

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# # # What is mean of 'Visiblity'

# %%
data['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# # #What is Standerd Deviation of 'Pressure' in Data ?

# %%
data['Press_kPa'].describe()
# Out:
# count    8784.000000
# mean      101.051623
# std         0.844005
# min        97.520000
# 25%       100.560000
# 50%       101.070000
# 75%       101.590000
# max       103.650000
# Name: Press_kPa, dtype: float64

# %%
#or
data['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %% [markdown]
# # # What is "Variance" of 'Relative Humidity' in data ?

# %%
data['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %% [markdown]
# # What is the Minimum and Maximum value of Each Coloumn Against Each 'Weather' ?

# %%
data.groupby('Weather').min().head()#it will show the min value of each coloumn for Each type of Weather.
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                     1/11/2012 1:00   -23.3             -28.5         20
# Cloudy                    1/1/2012 17:00   -21.4             -26.8         18
# Drizzle                  1/23/2012 21:00     1.1              -0.2         74
# Drizzle,Fog              1/23/2012 20:00     0.0              -1.6         85
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather
# Clear                                  0           11.3      99.52
# Cloudy                                 0           11.3      98.39
# Drizzle                                0            6.4      97.84
# Drizzle,Fog                            0            1.0      98.65
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
data.groupby('Weather').max().head()#it will show the max value of each coloumn for Each type of Weather.
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                      9/9/2012 5:00    32.8              20.4         99
# Cloudy                    9/9/2012 23:00    30.5              22.6         99
# Drizzle                   9/30/2012 3:00    18.8              17.7         96
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1        100
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather
# Clear                                 33           48.3     103.63
# Cloudy                                54           48.3     103.65
# Drizzle                               30           25.0     101.56
# Drizzle,Fog                           28            9.7     102.07
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %% [markdown]
# # #Find All The instance When 'snow' was Recorded in Weather column

# %%
#data['Weather'].value_counts()
# Out:
# 8784

# %%
data[data['Weather']=='Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data[data['Weather'].str.contains('Snow')]#this will show us all the row where Snow is present ex.like- 'snow shower'
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# # #Show all The Record Where Weather is'Fog'.

# %%
data[data['Weather']=='Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# # #Find All the instance Where Releted Humidity is greator than or equal to 84 and Weather is Clear.

# %%
data[(data['Rel Hum_%'] <= 84) & (data['Weather']== 'Clear')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8637  12/25/2012 21:00    -9.7             -12.5         80                4
# 8638  12/25/2012 22:00   -10.9             -13.2         83                4
# 8639  12/25/2012 23:00   -10.4             -12.7         83               11
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# # #Find All the instance When 'Windspeed' is above 24 & Visibility is 25.

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# ## What is the Mean Value of Each Coloumn Against Each 'Weather' ?

# %%
data.groupby('Weather').mean().head()#suppose in 'Wind Speed_km/hr' when Weather is 'Clear' it will Show the mean values for 'clear'weather
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                    6.825716          0.089367  64.497738
# Cloudy                   7.970544          2.375810  69.592593
# Drizzle                  7.353659          5.504878  88.243902
# Drizzle,Fog              8.067500          7.033750  93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000
#
#                          Wind Speed_km/h  Visibility_km   Press_kPa
# Weather
# Clear                          10.557315      30.153243  101.587443
# Cloudy                         16.127315      26.625752  100.911441
# Drizzle                        16.097561      17.931707  100.435366
# Drizzle,Fog                    11.862500       5.257500  100.786625
# Drizzle,Ice Pellets,Fog        20.000000       4.000000  100.790000
